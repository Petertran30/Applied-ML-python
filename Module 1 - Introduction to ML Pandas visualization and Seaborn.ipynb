# %% [markdown]
# # Pandas Visualization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib notebook

# %%
# see the pre-defined styles provided.
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
np.random.seed(123)

df = pd.DataFrame({"A": np.random.randn(365).cumsum(0), 
                   "B": np.random.randn(365).cumsum(0) + 20,
                   "C": np.random.randn(365).cumsum(0) - 20},
                     index = pd.date_range("1/1/2018", periods = 365))

# %%
df.head();

# %%
_=plt.boxplot([df["A"], df["B"], df["C"]], whis = (1,99))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.style.use('seaborn-colorblind')
df.plot();
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#plt.style.use('seaborn-white')
df.plot();
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
dfnew = pd.DataFrame({"normal": np.random.normal(0.0,1.0,365).cumsum(0),
                     "random": np.random.random(365).cumsum(0),
                     "gamma": np.random.gamma(1, 1, 365).cumsum(0)}, 
                    index = pd.date_range("1/1/2021", periods = 365))
df.head()
# Out:
#                    A          B          C
# 2018-01-01 -1.085631  20.059291 -20.230904
# 2018-01-02 -0.088285  21.803332 -16.659325
# 2018-01-03  0.194693  20.835588 -17.055481
# 2018-01-04 -1.311601  21.255156 -17.093802
# 2018-01-05 -1.890202  21.462083 -19.518638

# %%
dfnew.describe()
# Out:
#            normal      random       gamma
# count  365.000000  365.000000  365.000000
# mean     6.687194   91.434457  170.352161
# std      3.836884   51.380073   98.551186
# min     -1.725890    0.777590    0.317005
# 25%      4.132031   47.108088   89.818322
# 50%      5.833774   91.026199  163.960412
# 75%      8.126337  136.206329  260.555787
# max     19.411764  179.299740  338.455444

# %%
dfnew.plot();
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import mpl_toolkits.axes_grid1.inset_locator as mpl_il

ax2 = mpl_il.inset_axes(plt.gca(), width = "50%", height = "40%", loc = 2)
ax2.boxplot([dfnew["normal"],dfnew["random"],dfnew["gamma"]])
ax2.margins(x = 0.5)
ax2.yaxis.tick_right()

# %%
plt.figure()
_ = plt.hist2d(dfnew["normal"],dfnew["random"], bins = 20);
plt.colorbar();
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
ax1 = plt.subplot(121)
plt.scatter(df["A"],df["B"])

ax2 = plt.subplot(122, sharey = ax1)
plt.scatter(df["A"],df["C"])
ax2.yaxis.tick_right()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# You can also choose the plot kind by using the `DataFrame.plot.kind` methods instead of providing the `kind` keyword argument.
#
# `kind` :
# - `'line'` : line plot (default)
# - `'bar'` : vertical bar plot
# - `'barh'` : horizontal bar plot
# - `'hist'` : histogram
# - `'box'` : boxplot
# - `'kde'` : Kernel Density Estimation plot
# - `'density'` : same as 'kde'
# - `'area'` : area plot
# - `'pie'` : pie plot
# - `'scatter'` : scatter plot
# - `'hexbin'` : hexbin plot

# %%
plt.figure()
ax1 = plt.subplot(121)
plt.scatter(df["A"],df["B"])

ax2 = plt.subplot(122)
plt.scatter(df["A"],df["C"])
ax2.yaxis.tick_right()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# create a scatter plot of columns 'A' and 'C', with changing color (c) and size (s) based on column 'B'
df.plot.scatter('A', 'C', c='B', s=df['B'], colormap='viridis')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='A', ylabel='C'>

# %%
# set aspect of axes equal (same scale)
ax = df.plot.scatter('A', 'C', c='B', s=df['B'], colormap='viridis')
ax.set_aspect('equal')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df.plot.hist(alpha=0.3); # alpha is used to adjust the degree (%) of colors to be rendered
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df.plot.hist(alpha=0.7);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df.plot.hist?

# %%
df.plot.hist(alpha=1);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df.plot.kde(); # kernel density plot
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Pandas.plotting

# %% [markdown]
# iris flower dataset

# %%
# load the Iris dataset from local computer
"E:\Minh Phong\Tam\Data science coursera\Apply data science with Python\Applied Plotting, Charting & Data Representation in Python\resources"
import pandas as pd
import os
os.chdir(r"E:\Minh Phong\Tam\Data science coursera\Apply data science with Python\Applied Plotting, Charting & Data Representation in Python\resources")
iris = pd.read_csv("iris.csv")
iris.Name.unique()
# len(iris[iris.Name == "Iris-setosa"])
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
#another way to load iris dataset, iris come built-in in scikit module and can be loaded from the module
from sklearn import datasets
iris = datasets.load_iris()
print(iris.keys())
# print(iris.feature_names)
# print(iris.target_names)
#print(iris.target)
# print(len(iris.target_names))
iris.data.shape
irisdata = pd.DataFrame(iris.data, columns = iris.feature_names)
# irisdata["Name"] = ""

# filling Name for instances
Name = []
for i in range(150):
    #print(i)
    if i <=49:
        Name.append("Setosa")
    elif i <=99:
        Name.append("Versicolor")
    else:
        Name.append("Virginica")

irisdata["Name"] = Name
irisdata.head()

irisdata.head()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
Name = []
for i in range(150):
    #print(i)
    if i <=49:
        Name.append("Setosa")
    elif i <=99:
        Name.append("Versicolor")
    else:
        Name.append("Virginica")
#Name = pd.Series(Name)
Name

irisdata["Name"] = Name
irisdata.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#      Name
# 0  Setosa
# 1  Setosa
# 2  Setosa
# 3  Setosa
# 4  Setosa

# %%
iris.describe();
iris.Name.unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
# create a scatter matrix of all variables
#plt.figure(figsize=(12,8))
pd.plotting.scatter_matrix(iris); # pd.tools.plotting.scatter_matrix(iris) produces an error

colors = iris.Name.replace({'Iris-setosa':1, 'Iris-versicolor': 2, 'Iris-virginica':3})
pd.plotting.scatter_matrix(frame = features, c = colors, figsize = (9,9), s = 50);
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="900">

# %%
pd.plotting.scatter_matrix?
# Out:
# <function pandas.plotting._misc.scatter_matrix(frame, alpha=0.5, figsize=None, ax=None, grid=False, diagonal='hist', marker='.', density_kwds=None, hist_kwds=None, range_padding=0.05, **kwargs)>

# %%
iris.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:>

# %%
plt.figure()
pd.plotting.parallel_coordinates(iris, "Name")
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:>

# %% [markdown]
# # Seaborn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib notebook

# %%
np.random.seed(1234)

v1 = pd.Series(np.random.normal(0,10,1000))
v2 = pd.Series(2*v1 + np.random.normal(60,15,1000))

# %%
v1.describe()
# Out:
# count    1000.000000
# mean        0.157406
# std         9.735531
# min       -35.635167
# 25%        -6.243196
# 50%         0.177609
# 75%         6.688061
# max        27.638441
# dtype: float64

# %%
v2.describe()
# Out:
# count    1000.000000
# mean       60.941240
# std        24.621027
# min       -14.560396
# 25%        44.617209
# 50%        60.345791
# 75%        77.060348
# max       137.050122
# dtype: float64

# %%
plt.figure()
plt.hist(v1, alpha = 0.7, bins=np.arange(-50,150,5), label = "v1") # bins is set to imclude the wider range among two series
plt.hist(v2, alpha = 0.7, bins=np.arange(-50,150,5), label = "v2")
plt.legend(frameon = False)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# plot a kernel density estimation over a stacked barchart
plt.figure()
plt.hist([v1,v2], histtype = "barstacked", density = True);

v3 = np.concatenate((v1,v2))
sns.kdeplot(v3)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:ylabel='Density'>

# %%
plt.figure()
# we can pass keyword arguments for each individual component of the plot
sns.distplot(v3, hist_kws={'color': 'Teal'}, kde_kws={'color': 'Navy'});
# Out:
# <img src="data:image/png;base64,..." width="640">
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.jointplot(v1, v2, alpha = 0.4);
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <img src="data:image/png;base64,..." width="600">

# %%
grid = sns.jointplot(v1, v2, alpha = 0.4);
grid.ax_joint.set_aspect('equal')
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <img src="data:image/png;base64,..." width="600">

# %%
sns.jointplot?

# %%
grid = sns.jointplot(v1, v2, alpha = 0.4, xlim = (-60, 100))
grid.ax_joint.set_aspect("equal")
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <img src="data:image/png;base64,..." width="600">

# %%
plt.figure()
sns.jointplot(v1,v2, kind = "hex")
# Out:
# <img src="data:image/png;base64,..." width="640">
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <img src="data:image/png;base64,..." width="600">

# %%
# set the seaborn style for all the following plots
sns.set_style('white')

sns.jointplot(v1, v2, kind='kde', space=0); # space = 0 to tell seaborn that we donot want space between subplots
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <img src="data:image/png;base64,..." width="600">

# %%
iris = pd.read_csv('iris.csv')
iris.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
sns.pairplot(iris, hue = "Name", diag_kind = "kde", size = 2);
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# <img src="data:image/png;base64,..." width="932">

# %%
sns.pairplot(iris, hue = "Name", diag_kind = "hist", size = 2);
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# <img src="data:image/png;base64,..." width="944">

# %%
plt.figure(figsize = (8,6))

plt.subplot(121)
sns.swarmplot(x = "Name", y = "PetalLength", data = iris);
plt.subplot(122)
sns.violinplot("Name", "PetalLength", data = iris);
# Out:
# <img src="data:image/png;base64,..." width="800">
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 8.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.swarmplot?
